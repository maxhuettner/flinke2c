# %%
import importlib

import utils

importlib.reload(utils)

from utils.exp_utils import process_experiments, prepare_exp_data, process_experiments_paper, prepare_relative_exp_data, prepare_nebula_event_throughput_data, prepare_nebula_event_boxplot_summary
from utils.plot_utils import ecdf_plot, event_throughput_line_plot, event_throughput_boxplot
import matplotlib.pyplot as plt
import seaborn as sns
from utils.gen_plot_data import gen_ecdf_data, gen_kde_data, gen_event_line_data

sns.set_theme()

# plt.style.use('ggplot')

# %% [markdown]
# # Intro

# %%
data = process_experiments_paper("flink_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (Flink | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "intro_q1",output_suffix="paper", x_label="Relative Throughput")

# %% [markdown]
# # Requirements

# %%
data = process_experiments("data_nm", names=["base_hom_hom_q1", "slowcoord100mbps_hom_hom_q1"])
throughput_data = prepare_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Throughput (tps)", title="Relative Throughput (Nexmark | Q1 | higher is better)")
plt.show()
gen_ecdf_data(throughput_data, "limitations_slow_coordinator")

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Flink

# %%
data = process_experiments_paper("flink_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (Flink | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_limitations_q1",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            831136
# Edge-to-Cloud    794241
# Mixed            827073
# Name: abs_value, dtype: int64

# %%
data = process_experiments(path="data/nes_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (NES | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "nes_limitations_q1",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            235037
# Edge-to-Cloud    234219
# Mixed            236306
# Name: abs_value, dtype: int64

# %%
data = process_experiments_paper("flink_q4", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (Flink | Q4 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_limitations_q4",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            62888
# Edge-to-Cloud    26105
# Mixed            61051
# Name: abs_value, dtype: int64

# %%
data = process_experiments_paper("nes_q4", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (NES | Q4 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "nes_limitations_q4",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            457476
# Edge-to-Cloud    142044
# Mixed            462738
# Name: abs_value, dtype: int64

# %%
data = process_experiments_paper("flink_q5", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (Flink | Q5 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_limitations_q5",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            65637
# Edge-to-Cloud    63936
# Mixed            62281
# Name: abs_value, dtype: int64

# %%
data = process_experiments_paper("nes_q5", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (NES | Q5 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "nes_limitations_q5",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            342857
# Edge-to-Cloud    130134
# Mixed            343911
# Name: abs_value, dtype: int64

# %%
data = process_experiments(path="data/flink_top_down_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (FlinkE2C Top-Down | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_td_q1",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            850041
# Edge-to-Cloud    867515
# Mixed            829725
# Name: abs_value, dtype: int64

# %%
data = process_experiments_paper("flink_bottom_up_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (FlinkE2C Bottom-Up | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_bu_q1",output_suffix="paper", x_label="Relative Throughput")

# %%
data = process_experiments_paper("flink_top_down_q4", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (FlinkE2C Top-Down | Q4 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_td_q4",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            60956
# Edge-to-Cloud    27023
# Mixed            60453
# Name: abs_value, dtype: int64

# %%
data = process_experiments_paper("flink_top_down_q5", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_relative_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput Distribution (FlinkE2C Top-Down | Q5 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_td_q5",output_suffix="paper", x_label="Relative Throughput")
print(throughput_data.groupby("exp_name").max()["abs_value"])
# Out:
# exp_name
# Cloud            67136
# Edge-to-Cloud    59375
# Mixed            66047
# Name: abs_value, dtype: int64

# %% [markdown]
# # Absolute

# %%
data = process_experiments_paper("flink_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput (Flink | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_abs_q1",output_suffix="paper", x_label="Throughput (tps)")

# %%
data = process_experiments_paper("flink_q4", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput (Flink | Q4 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_abs_q4",output_suffix="paper", x_label="Throughput (tps)")

# %%
data = process_experiments(path="data/flink_top_down_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput (FlinkE2C Top-Down | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_td_abs_q1",output_suffix="paper", x_label="Throughput (tps)")

# %%
data = process_experiments_paper("flink_top_down_q4", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput (FlinkE2C Top-Down | Q4 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_td_abs_q4",output_suffix="paper", x_label="Throughput (tps)")

# %%
data = process_experiments_paper("flink_bottom_up_q1", names=["hom_hom", "hom_het", "het_het"])
throughput_data = prepare_exp_data(data, "throughput")

ecdf_plot(throughput_data, x_name="Relative Throughput", title="Throughput (FlinkE2C Bottom-Up | Q1 | higher is better)", is_int_axis=False)
plt.show()
gen_ecdf_data(throughput_data, "flink_placement_bu_abs_q1",output_suffix="paper", x_label="Throughput (tps)")

# %%
data = process_experiments_paper("flink_cepless", names=["het_het"])
event_data = prepare_nebula_event_throughput_data(data)

event_throughput_line_plot(event_data, x_name="Relative Throughput", title="Throughput (CEPless | higher is better)")
event_throughput_boxplot(event_data, x_name="Relative Throughput", title="Throughput (CEPless | higher is better)")
plt.show()
event_df = prepare_nebula_event_throughput_data(data, smooth_window=2)
line_meta = gen_event_line_data(event_df, "flink_cepless_line", output_suffix="paper", use_smoothed=True)

# %%
data = process_experiments_paper("flink_cepless_top_down", names=["het_het"])
event_data = prepare_nebula_event_throughput_data(data)

event_throughput_line_plot(event_data, x_name="Relative Throughput", title="Throughput (CEPless | higher is better)")
event_throughput_boxplot(event_data, x_name="Relative Throughput", title="Throughput (CEPless | higher is better)")
plt.show()
event_df = prepare_nebula_event_throughput_data(data)
line_meta = gen_event_line_data(event_df, "flink_cepless_top_down", output_suffix="paper", use_smoothed=True)

# %%
data = process_experiments_paper("flink_cepless_bottom_up", names=["het_het"])
event_data = prepare_nebula_event_throughput_data(data)

event_throughput_line_plot(event_data, x_name="Relative Throughput", title="Throughput (CEPless | higher is better)")
event_throughput_boxplot(event_data, x_name="Relative Throughput", title="Throughput (CEPless | higher is better)")
plt.show()
event_df = prepare_nebula_event_throughput_data(data)
line_meta = gen_event_line_data(event_df, "flink_cepless_bottom_up", output_suffix="paper", use_smoothed=True)
# Out:
# /home/max/dev/flinke2c/experiments/utils/exp_utils.py:212: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   events_df[time_col] = pd.to_datetime(events_df[time_col], errors="coerce")
